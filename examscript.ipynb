# %%
import os
import numpy as np
import matplotlib.pyplot as plt
start_time = datetime.now()
output = open('x.txt', 'w')
output = open('8atoms.txt', 'w')

with open('samplecartesian.pw.in') as f:
    lines = f.readlines()
for dm in np.arange(5, 16, 0.5):
    lines[9] = '                   celldm(1) =  {},'.format(dm)
    with open('input.in', 'w') as f:
        for l in lines:
             f.write(l)
    os.system('../bin/pw.x < input.in > output.txt')
    with open ('output.txt')as f:
        for l in f.readlines():
            if '!' in l:

                print(dm, l[38:44])
                output = open('x.txt', 'a' )
                print(dm, file= output)
                output = open('8atoms.txt', 'a')
                print(l[38:44], file= output )
                output.close()
# Out:
# 5.0 15.371
# 5.5 29.354
# 6.0 38.428
# 7.0 50.844
# 7.5 55.303
# 8.0 58.178
# 8.5 60.020
# 9.0 61.152
# 9.5 61.796
# 10.0 62.124
# 10.5 62.230
# 11.0 62.199
# 11.5 62.078
# 12.0 61.919
# 12.5 61.752
# 13.0 61.587
# 13.5 61.433
# 14.5 61.101
# 15.0 61.011

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

data8atomsfullenergy = np.loadtxt("8atoms.txt", delimiter='\t', dtype=np.float)
data7atomsfullenergy = np.loadtxt("7atoms.txt", delimiter='\t', dtype=np.float)
сa = 0.875
atoms78 = 0.875*data8atomsfullenergy
ryd = (data7atomsfullenergy - atoms78)*13.605
x = np.loadtxt("x.txt", delimiter='\t', dtype=np.float)
y = abs(ryd)
plt.title('энергия формирования вакансии от параметра решетки ячейки')
plt.xlabel('параметр решетки (alat)')
plt.ylabel('энергия образования вакансии (eV)')
plt.grid()
plt.plot(x, y, 'g')

# %% [markdown]
# ![2020-06-27%2000-53-27%20BURAI1.3,%20a%20GUI%20of%20Quantum%20ESPRESSO..jpg](attachment:2020-06-27%2000-53-27%20BURAI1.3,%20a%20GUI%20of%20Quantum%20ESPRESSO..jpg)

# %% [markdown]
# #    input. file middle iteration
#  &CONTROL
#                  calculation = 'scf' ,
#                       outdir = '/mnt/d/qe-6.5/exam/' ,
#                       wfcdir = '/mnt/d/qe-6.5/exam/' ,
#                   pseudo_dir = '/mnt/d/qe-6.5/exam/' ,
#                       prefix = 'fractional' ,
#  /
#  &SYSTEM
#                        ibrav = 1,
#                    celldm(1) = 10.6713816318,
#                          nat = 8,
#                         ntyp = 1,
#                      ecutwfc = 15 ,
#                      ecutrho = 60 ,
#  /
#  &ELECTRONS
#  /
# ATOMIC_SPECIES
#    Si   28.08550  Si.pbe-rrkj.UPF
# ATOMIC_POSITIONS alat
# Si 0.000 0.000 0.000
# Si 0.500 0.500 0.000
# Si 0.500 0.000 0.500
# Si 0.000 0.500 0.500
#
# Si 0.250 0.250 0.250
# Si 0.250 0.750 0.750
# Si 0.750 0.250 0.750
# Si 0.750 0.750 0.250
#
#
#
#
# K_POINTS automatic
#   1 1 1   1 1 1

# %% [markdown]
# #     output.file final iteration
#     Program PWSCF v.6.5 starts on 27Jun2020 at  0:28:30
#
#      This program is part of the open-source Quantum ESPRESSO suite
#      for quantum simulation of materials; please cite
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 21 395502 (2009);
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 29 465901 (2017);
#           URL http://www.quantum-espresso.org",
#      in publications or presentations arising from this work. More details at
#      http://www.quantum-espresso.org/quote
#
#      Parallel version (MPI), running on     1 processors
#
#      MPI processes distributed on     1 nodes
#      Waiting for input...
#      Reading input from standard input
#
#      Current dimensions of program PWSCF are:
#      Max number of different atomic species (ntypx) = 10
#      Max number of k-points (npk) =  40000
#      Max angular momentum in pseudopotentials (lmaxx) =  3
#
#      Subspace diagonalization in iterative solution of the eigenvalue problem:
#      a serial algorithm will be used
#
#      Found symmetry operation: I + ( -0.5000 -0.5000  0.0000)
#      This is a supercell, fractional translations are disabled
#
#      G-vector sticks info
#      --------------------
#      sticks:   dense  smooth     PW     G-vecs:    dense   smooth      PW
#      Sum        1153    1153    341                29279    29279    4729
#
#
#
#      bravais-lattice index     =            1
#      lattice parameter (alat)  =      15.5000  a.u.
#      unit-cell volume          =    3723.8750 (a.u.)^3
#      number of atoms/cell      =            8
#      number of atomic types    =            1
#      number of electrons       =        32.00
#      number of Kohn-Sham states=           16
#      kinetic-energy cutoff     =      15.0000  Ry
#      charge density cutoff     =      60.0000  Ry
#      convergence threshold     =      1.0E-06
#      mixing beta               =       0.7000
#      number of iterations used =            8  plain     mixing
#      Exchange-correlation=  SLA  PW   PBE  PBE
#                            (   1   4   3   4   0   0   0)
#
#      celldm(1)=  15.500000  celldm(2)=   0.000000  celldm(3)=   0.000000
#      celldm(4)=   0.000000  celldm(5)=   0.000000  celldm(6)=   0.000000
#
#      crystal axes: (cart. coord. in units of alat)
#                a(1) = (   1.000000   0.000000   0.000000 )
#                a(2) = (   0.000000   1.000000   0.000000 )
#                a(3) = (   0.000000   0.000000   1.000000 )
#
#      reciprocal axes: (cart. coord. in units 2 pi/alat)
#                b(1) = (  1.000000  0.000000  0.000000 )
#                b(2) = (  0.000000  1.000000  0.000000 )
#                b(3) = (  0.000000  0.000000  1.000000 )
#
#
#      PseudoPot. # 1 for Si read from file:
#      /mnt/d/qe-6.5/exam/Si.pbe-rrkj.UPF
#      MD5 check sum: cf7ab5690cd9a85b22c4813f7e365554
#      Pseudo is Norm-conserving, Zval =  4.0
#      Generated by new atomic code, or converted to UPF format
#      Using radial grid of  883 points,  3 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#                 l(3) =   1
#
#      atomic species   valence    mass     pseudopotential
#         Si             4.00    28.08550     Si( 1.00)
#
#      24 Sym. Ops. (no inversion) found
#
#
#
#    Cartesian axes
#
#      site n.     atom                  positions (alat units)
#          1           Si  tau(   1) = (   0.0000000   0.0000000   0.0000000  )
#          2           Si  tau(   2) = (   0.5000000   0.5000000   0.0000000  )
#          3           Si  tau(   3) = (   0.5000000   0.0000000   0.5000000  )
#          4           Si  tau(   4) = (   0.0000000   0.5000000   0.5000000  )
#          5           Si  tau(   5) = (   0.2500000   0.2500000   0.2500000  )
#          6           Si  tau(   6) = (   0.2500000   0.7500000   0.7500000  )
#          7           Si  tau(   7) = (   0.7500000   0.2500000   0.7500000  )
#          8           Si  tau(   8) = (   0.7500000   0.7500000   0.2500000  )
#
#      number of k points=     1
#                        cart. coord. in units 2pi/alat
#         k(    1) = (  -0.5000000  -0.5000000  -0.5000000), wk =   2.0000000
#
#      Dense  grid:    29279 G-vectors     FFT dimensions: (  40,  40,  40)
#
#      Estimated max dynamical RAM per process >      27.29 MB
#
#      Initial potential from superposition of free atoms
#
#      starting charge   31.99557, renormalised to   32.00000
#      Starting wfcs are   32 randomized atomic wfcs
#
#      total cpu time spent up to now is        0.2 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.00E-02,  avg # of iterations =  1.0
#
#      Threshold (ethr) on eigenvalues was too large:
#      Diagonalizing with lowered threshold
#
#      Davidson diagonalization with overlap
#      ethr =  8.24E-05,  avg # of iterations =  3.0
#
#      total cpu time spent up to now is        0.5 secs
#
#      total energy              =     -60.98624473 Ry
#      Harris-Foulkes estimate   =     -60.98933258 Ry
#      estimated scf accuracy    <       0.02187810 Ry
#
#      iteration #  2     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  6.84E-05,  avg # of iterations =  9.0
#
#      total cpu time spent up to now is        0.8 secs
#
#      total energy              =     -60.96843903 Ry
#      Harris-Foulkes estimate   =     -61.01087465 Ry
#      estimated scf accuracy    <       0.36189718 Ry
#
#      iteration #  3     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  6.84E-05,  avg # of iterations =  8.0
#
#      total cpu time spent up to now is        1.0 secs
#
#      total energy              =     -60.98316078 Ry
#      Harris-Foulkes estimate   =     -61.00434939 Ry
#      estimated scf accuracy    <       0.40982135 Ry
#
#      iteration #  4     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  6.84E-05,  avg # of iterations =  3.0
#
#      total cpu time spent up to now is        1.2 secs
#
#      total energy              =     -60.97351094 Ry
#      Harris-Foulkes estimate   =     -60.98449434 Ry
#      estimated scf accuracy    <       0.31541796 Ry
#
#      iteration #  5     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  6.84E-05,  avg # of iterations =  1.0
#
#      total cpu time spent up to now is        1.3 secs
#
#      total energy              =     -60.95266870 Ry
#      Harris-Foulkes estimate   =     -60.97418094 Ry
#      estimated scf accuracy    <       0.27671939 Ry
#
#      iteration #  6     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  6.84E-05,  avg # of iterations =  9.0
#
#      total cpu time spent up to now is        1.5 secs
#
#      total energy              =     -60.98718118 Ry
#      Harris-Foulkes estimate   =     -60.98677041 Ry
#      estimated scf accuracy    <       0.00562493 Ry
#
#      iteration #  7     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.76E-05,  avg # of iterations =  3.0
#
#      total cpu time spent up to now is        1.7 secs
#
#      total energy              =     -60.98674257 Ry
#      Harris-Foulkes estimate   =     -60.98789280 Ry
#      estimated scf accuracy    <       0.01064788 Ry
#
#      iteration #  8     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.76E-05,  avg # of iterations =  3.0
#
#      total cpu time spent up to now is        1.8 secs
#
#      total energy              =     -60.98673991 Ry
#      Harris-Foulkes estimate   =     -60.98698359 Ry
#      estimated scf accuracy    <       0.00705263 Ry
#
#      iteration #  9     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.76E-05,  avg # of iterations =  1.0
#
#      total cpu time spent up to now is        1.9 secs
#
#      total energy              =     -60.98653524 Ry
#      Harris-Foulkes estimate   =     -60.98678561 Ry
#      estimated scf accuracy    <       0.00619279 Ry
#
#      iteration # 10     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.76E-05,  avg # of iterations =  1.0
#
#      total cpu time spent up to now is        2.1 secs
#
#      total energy              =     -60.98632974 Ry
#      Harris-Foulkes estimate   =     -60.98656967 Ry
#      estimated scf accuracy    <       0.00509151 Ry
#
#      iteration # 11     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.59E-05,  avg # of iterations =  1.0
#
#      total cpu time spent up to now is        2.2 secs
#
#      total energy              =     -60.98590394 Ry
#      Harris-Foulkes estimate   =     -60.98636092 Ry
#      estimated scf accuracy    <       0.00433874 Ry
#
#      iteration # 12     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  1.36E-05,  avg # of iterations =  1.0
#
#      total cpu time spent up to now is        2.3 secs
#
#      total energy              =     -60.98579239 Ry
#      Harris-Foulkes estimate   =     -60.98598384 Ry
#      estimated scf accuracy    <       0.00267104 Ry
#
#      iteration # 13     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  8.35E-06,  avg # of iterations =  1.0
#
#      total cpu time spent up to now is        2.5 secs
#
#      total energy              =     -60.98583918 Ry
#      Harris-Foulkes estimate   =     -60.98585307 Ry
#      estimated scf accuracy    <       0.00209460 Ry
#
#      iteration # 14     ecut=    15.00 Ry     beta= 0.70
#      Davidson diagonalization with overlap
#      ethr =  6.55E-06,  avg # of iterations =  1.0
#
#      total cpu time spent up to now is        2.6 secs
#
#      End of self-consistent calculation
#
#      convergence NOT achieved after 100 iterations: stopping
#
#      Writing output data file /mnt/d/qe-6.5/exam/fractional.save/
#      Message from routine punch:
#      wavefunctions written to file
#
#      init_run     :      0.20s CPU      0.20s WALL (       1 calls)
#      electrons    :     24.08s CPU     24.39s WALL (       1 calls)
#
#      Called by init_run:
#      wfcinit      :      0.08s CPU      0.09s WALL (       1 calls)
#      potinit      :      0.06s CPU      0.05s WALL (       1 calls)
#      hinit0       :      0.05s CPU      0.04s WALL (       1 calls)
#
#      Called by electrons:
#      c_bands      :     18.30s CPU     18.37s WALL (     101 calls)
#      sum_band     :      1.97s CPU      2.02s WALL (     101 calls)
#      v_of_rho     :      3.03s CPU      3.14s WALL (     101 calls)
#      mix_rho      :      0.73s CPU      0.82s WALL (     101 calls)
#
#      Called by c_bands:
#      init_us_2    :      0.22s CPU      0.19s WALL (     203 calls)
#      cegterg      :     18.03s CPU     18.14s WALL (     101 calls)
#
#      Called by sum_band:
#
#      Called by *egterg:
#      h_psi        :     12.81s CPU     12.80s WALL (     750 calls)
#      g_psi        :      0.11s CPU      0.13s WALL (     648 calls)
#      cdiaghg      :      0.44s CPU      0.44s WALL (     748 calls)
#
#      Called by h_psi:
#      h_psi:calbec :      1.38s CPU      1.37s WALL (     750 calls)
#      vloc_psi     :     10.06s CPU     10.07s WALL (     750 calls)
#      add_vuspsi   :      1.33s CPU      1.31s WALL (     750 calls)
#
#      General routines
#      calbec       :      1.38s CPU      1.37s WALL (     750 calls)
#      fft          :      1.48s CPU      1.50s WALL (    1011 calls)
#      ffts         :      0.16s CPU      0.10s WALL (     101 calls)
#      fftw         :     10.23s CPU     10.50s WALL (   15002 calls)
#      davcio       :      0.00s CPU      0.00s WALL (      19 calls)
#
#      Parallel routines
#
#      PWSCF        :     24.30s CPU     24.64s WALL
#
#
#    This run was terminated on:   0:28:54  27Jun2020
#
# =------------------------------------------------------------------------------=
#    JOB DONE.
# =------------------------------------------------------------------------------=
